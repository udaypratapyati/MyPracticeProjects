# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

a= np.random.choice(["option_{}".format(i) for i in [1,2,3]], size=(12,3))
# print(a)
df = pd.DataFrame(a, columns=["Attribute_{}".format(i) for i in list("ABC")])
df.head(3)
# sns.countplot(x="variable", hue="value", data=pd.melt(df))
# Out:
#   Attribute_A Attribute_B Attribute_C
# 0    option_1    option_2    option_2
# 1    option_2    option_1    option_1
# 2    option_3    option_1    option_2

# %%
list(df.columns)
# Out:
# ['Attribute_A', 'Attribute_B', 'Attribute_C']

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, sharey=True)
i=0
for col in ['Attribute_A', 'Attribute_B', 'Attribute_C']:
    print(i)
    sns.countplot(x=df[col], data=df, ax=axes[i])
    i += 1
    # axes[i].xticks(rotation=90)
# plt.xticks(rotation=90)
# Out:
# 0
# 1
# 2
